# %%
import numpy as np
import pandas as pd
import datetime
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# # Importing Amazon Sales Data

# %%
df = pd.read_csv('Amazon Sales data.csv')
df
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
#    Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# 0        Offline              H   5/28/2010  669165933   6/27/2010
# 1         Online              C   8/22/2012  963881480   9/15/2012
# 2        Offline              L    5/2/2014  341417157    5/8/2014
# 3         Online              C   6/20/2014  514321792    7/5/2014
# 4        Offline              L    2/1/2013  115456712    2/6/2013
# ..           ...            ...         ...        ...         ...
# 95        Online              M   7/26/2011  512878119    9/3/2011
# 96       Offline              L  11/11/2011  810711038  12/28/2011
# 97       Offline              C    6/1/2016  728815257   6/29/2016
# 98       Offline              M   7/30/2015  559427106    8/8/2015
# 99       Offline              L   2/10/2012  665095412   2/15/2012
#
#     Units Sold  Unit Price  Unit Cost  Total Revenue  Total Cost  Total Profit
# 0         9925      255.28     159.42     2533654.00  1582243.50     951410.50
# 1         2804      205.70     117.11      576782.80   328376.44     248406.36
# 2         1779      651.21     524.96     1158502.59   933903.84     224598.75
# 3         8102        9.33       6.92       75591.66    56065.84      19525.82
# 4         5062      651.21     524.96     3296425.02  2657347.52     639077.50
# ..         ...         ...        ...            ...         ...           ...
# 95         888      109.28      35.84       97040.64    31825.92      65214.72
# 96        6267        9.33       6.92       58471.11    43367.64      15103.47
# 97        1485      154.06      90.93      228779.10   135031.05      93748.05
# 98        5767       81.73      56.67      471336.91   326815.89     144521.02
# 99        5367      668.27     502.54     3586605.09  2697132.18     889472.91
#
# [100 rows x 14 columns]

# %% [markdown]
# # Dataset Shape

# %%
df.shape
# Out:
# (100, 14)

# %% [markdown]
# # Getting info about  non-null and Dtype

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Region          100 non-null    object
#  1   Country         100 non-null    object
#  2   Item Type       100 non-null    object
#  3   Sales Channel   100 non-null    object
#  4   Order Priority  100 non-null    object
#  5   Order Date      100 non-null    object
#  6   Order ID        100 non-null    int64
#  7   Ship Date       100 non-null    object
#  8   Units Sold      100 non-null    int64
#  9   Unit Price      100 non-null    float64
#  10  Unit Cost       100 non-null    float64
#  11  Total Revenue   100 non-null    float64
#  12  Total Cost      100 non-null    float64
#  13  Total Profit    100 non-null    float64
# dtypes: float64(5), int64(2), object(7)
# memory usage: 11.1+ KB

# %% [markdown]
# # Finding Null Values

# %%
df.isnull().sum()
# Out:
# Region            0
# Country           0
# Item Type         0
# Sales Channel     0
# Order Priority    0
# Order Date        0
# Order ID          0
# Ship Date         0
# Units Sold        0
# Unit Price        0
# Unit Cost         0
# Total Revenue     0
# Total Cost        0
# Total Profit      0
# dtype: int64

# %% [markdown]
# # Classification of Data Types

# %%
df.dtypes == 'object'
# Out:
# Region             True
# Country            True
# Item Type          True
# Sales Channel      True
# Order Priority     True
# Order Date         True
# Order ID          False
# Ship Date          True
# Units Sold        False
# Unit Price        False
# Unit Cost         False
# Total Revenue     False
# Total Cost        False
# Total Profit      False
# dtype: bool

# %%
df.dtypes == 'int64'
# Out:
# Region            False
# Country           False
# Item Type         False
# Sales Channel     False
# Order Priority    False
# Order Date        False
# Order ID           True
# Ship Date         False
# Units Sold         True
# Unit Price        False
# Unit Cost         False
# Total Revenue     False
# Total Cost        False
# Total Profit      False
# dtype: bool

# %%
df.dtypes == 'float64'
# Out:
# Region            False
# Country           False
# Item Type         False
# Sales Channel     False
# Order Priority    False
# Order Date        False
# Order ID          False
# Ship Date         False
# Units Sold        False
# Unit Price         True
# Unit Cost          True
# Total Revenue      True
# Total Cost         True
# Total Profit       True
# dtype: bool

# %% [markdown]
# # Columns of Dataset

# %%
df.columns
# Out:
# Index(['Region', 'Country', 'Item Type', 'Sales Channel', 'Order Priority',
#        'Order Date', 'Order ID', 'Ship Date', 'Units Sold', 'Unit Price',
#        'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit'],
#       dtype='object')

# %% [markdown]
# # Converting Date Object to datetime

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Ship Date'] = pd.to_datetime(df['Ship Date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Region          100 non-null    object
#  1   Country         100 non-null    object
#  2   Item Type       100 non-null    object
#  3   Sales Channel   100 non-null    object
#  4   Order Priority  100 non-null    object
#  5   Order Date      100 non-null    datetime64[ns]
#  6   Order ID        100 non-null    int64
#  7   Ship Date       100 non-null    datetime64[ns]
#  8   Units Sold      100 non-null    int64
#  9   Unit Price      100 non-null    float64
#  10  Unit Cost       100 non-null    float64
#  11  Total Revenue   100 non-null    float64
#  12  Total Cost      100 non-null    float64
#  13  Total Profit    100 non-null    float64
# dtypes: datetime64[ns](2), float64(5), int64(2), object(5)
# memory usage: 11.1+ KB

# %%
df.columns
# Out:
# Index(['Region', 'Country', 'Item Type', 'Sales Channel', 'Order Priority',
#        'Order Date', 'Order ID', 'Ship Date', 'Units Sold', 'Unit Price',
#        'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit'],
#       dtype='object')

# %% [markdown]
# # Number of Days for Delivery of orders

# %%
df['Delivery days'] = (df['Ship Date']-df['Order Date'])
df
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
#    Sales Channel Order Priority Order Date   Order ID  Ship Date  Units Sold  \
# 0        Offline              H 2010-05-28  669165933 2010-06-27        9925
# 1         Online              C 2012-08-22  963881480 2012-09-15        2804
# 2        Offline              L 2014-05-02  341417157 2014-05-08        1779
# 3         Online              C 2014-06-20  514321792 2014-07-05        8102
# 4        Offline              L 2013-02-01  115456712 2013-02-06        5062
# ..           ...            ...        ...        ...        ...         ...
# 95        Online              M 2011-07-26  512878119 2011-09-03         888
# 96       Offline              L 2011-11-11  810711038 2011-12-28        6267
# 97       Offline              C 2016-06-01  728815257 2016-06-29        1485
# 98       Offline              M 2015-07-30  559427106 2015-08-08        5767
# 99       Offline              L 2012-02-10  665095412 2012-02-15        5367
#
#     Unit Price  Unit Cost  Total Revenue  Total Cost  Total Profit  \
# 0       255.28     159.42     2533654.00  1582243.50     951410.50
# 1       205.70     117.11      576782.80   328376.44     248406.36
# 2       651.21     524.96     1158502.59   933903.84     224598.75
# 3         9.33       6.92       75591.66    56065.84      19525.82
# 4       651.21     524.96     3296425.02  2657347.52     639077.50
# ..         ...        ...            ...         ...           ...
# 95      109.28      35.84       97040.64    31825.92      65214.72
# 96        9.33       6.92       58471.11    43367.64      15103.47
# 97      154.06      90.93      228779.10   135031.05      93748.05
# 98       81.73      56.67      471336.91   326815.89     144521.02
# 99      668.27     502.54     3586605.09  2697132.18     889472.91
#
#    Delivery days
# 0        30 days
# 1        24 days
# 2         6 days
# 3        15 days
# 4         5 days
# ..           ...
# 95       39 days
# 96       47 days
# 97       28 days
# 98        9 days
# 99        5 days
#
# [100 rows x 15 columns]

# %% [markdown]
# # Extracting Year,Quarter,Month,Day from Amazon Sales Data

# %%
df['Order Year']=df['Order Date'].dt.year
df['Order Month']=df['Order Date'].dt.month
df['Order Quarter']=df['Order Date'].dt.quarter
df['Order Day']=df['Order Date'].dt.day
df
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
#    Sales Channel Order Priority Order Date   Order ID  Ship Date  Units Sold  \
# 0        Offline              H 2010-05-28  669165933 2010-06-27        9925
# 1         Online              C 2012-08-22  963881480 2012-09-15        2804
# 2        Offline              L 2014-05-02  341417157 2014-05-08        1779
# 3         Online              C 2014-06-20  514321792 2014-07-05        8102
# 4        Offline              L 2013-02-01  115456712 2013-02-06        5062
# ..           ...            ...        ...        ...        ...         ...
# 95        Online              M 2011-07-26  512878119 2011-09-03         888
# 96       Offline              L 2011-11-11  810711038 2011-12-28        6267
# 97       Offline              C 2016-06-01  728815257 2016-06-29        1485
# 98       Offline              M 2015-07-30  559427106 2015-08-08        5767
# 99       Offline              L 2012-02-10  665095412 2012-02-15        5367
#
#     Unit Price  Unit Cost  Total Revenue  Total Cost  Total Profit  \
# 0       255.28     159.42     2533654.00  1582243.50     951410.50
# 1       205.70     117.11      576782.80   328376.44     248406.36
# 2       651.21     524.96     1158502.59   933903.84     224598.75
# 3         9.33       6.92       75591.66    56065.84      19525.82
# 4       651.21     524.96     3296425.02  2657347.52     639077.50
# ..         ...        ...            ...         ...           ...
# 95      109.28      35.84       97040.64    31825.92      65214.72
# 96        9.33       6.92       58471.11    43367.64      15103.47
# 97      154.06      90.93      228779.10   135031.05      93748.05
# 98       81.73      56.67      471336.91   326815.89     144521.02
# 99      668.27     502.54     3586605.09  2697132.18     889472.91
#
#    Delivery days  Order Year  Order Month  Order Quarter  Order Day
# 0        30 days        2010            5              2         28
# 1        24 days        2012            8              3         22
# 2         6 days        2014            5              2          2
# 3        15 days        2014            6              2         20
# 4         5 days        2013            2              1          1
# ..           ...         ...          ...            ...        ...
# 95       39 days        2011            7              3         26
# 96       47 days        2011           11              4         11
# 97       28 days        2016            6              2          1
# 98        9 days        2015            7              3         30
# 99        5 days        2012            2              1         10
#
# [100 rows x 19 columns]

# %% [markdown]
# # Region Wise Contribution

# %%
plt.figure(figsize = (8,8))
plt.title('Region')
plt.pie(df['Region'].value_counts(), labels=df['Region'].value_counts().index,autopct='%1.1f%%')
plt.show()

# %% [markdown]
# Sub-Saharan Contribution is More than the other region

# %% [markdown]
# # Year Wise Sales

# %%
Year_Sales=df.groupby('Order Year')['Units Sold'].sum()
print(Year_Sales)
# Out:
# Order Year
# 2010    61571
# 2011    54768
# 2012    97967
# 2013    64663
# 2014    92040
# 2015    49480
# 2016    43156
# 2017    49226
# Name: Units Sold, dtype: int64

# %% [markdown]
# # Top 10 Highest Sales Country

# %%
sales_country = df.groupby(['Country'] , as_index = False)['Units Sold'].sum().sort_values(by='Units Sold',ascending = False)
Top10_sales_country = sales_country.head(10)
print(Top10_sales_country )
# Out:
#                   Country  Units Sold
# 59  Sao Tome and Principe       24568
# 16               Djibouti       23198
# 41                 Mexico       19143
# 71             The Gambia       14813
# 46                Myanmar       14180
# 2               Australia       12995
# 50                 Norway       12574
# 24               Honduras       11199
# 10               Cameroon       10948
# 73                 Tuvalu        9925

# %% [markdown]
# # Year-Month Wise Sales

# %%
monthly_sales = df.groupby(['Order Year', 'Order Month'])['Units Sold'].sum().reset_index()
monthly_sales_sorted = monthly_sales.sort_values(by=['Order Year','Order Month'])
print(monthly_sales_sorted)
# Out:
#     Order Year  Order Month  Units Sold
# 0         2010            2        9503
# 1         2010            5       15747
# 2         2010            6        9905
# 3         2010           10       14403
# 4         2010           11        7910
# 5         2010           12        4103
# 6         2011            1       12914
# 7         2011            2        8156
# 8         2011            4        4187
# 9         2011            5        5741
# 10        2011            6         124
# 11        2011            7         888
# 12        2011            9        3732
# 13        2011           11       19026
# 14        2012            1        1548
# 15        2012            2       15776
# 16        2012            3        6457
# 17        2012            4        8903
# 18        2012            5       10984
# 19        2012            6        7620
# 20        2012            7       22646
# 21        2012            8        2804
# 22        2012            9       16545
# 23        2012           10        4684
# 24        2013            2        5062
# 25        2013            3        4063
# 26        2013            4        5010
# 27        2013            6        5432
# 28        2013            7       19546
# 29        2013            8        9606
# 30        2013            9        7637
# 31        2013           10        6182
# 32        2013           12        2125
# 33        2014            2       10460
# 34        2014            4       13808
# 35        2014            5        9229
# 36        2014            6        8102
# 37        2014            7       14513
# 38        2014            8        4168
# 39        2014            9        2187
# 40        2014           10       22619
# 41        2014           11        6954
# 42        2015            1        8250
# 43        2015            2        5821
# 44        2015            4       12772
# 45        2015            7       13110
# 46        2015            8         673
# 47        2015           10        2924
# 48        2015           11        5930
# 49        2016            3         962
# 50        2016            5        5070
# 51        2016            6        3710
# 52        2016            7        5498
# 53        2016           10        4660
# 54        2016           11       13441
# 55        2016           12        9815
# 56        2017            1       13030
# 57        2017            2       16301
# 58        2017            3        3015
# 59        2017            5       16880

# %% [markdown]
# # Year Wise Units Sold in Top Order

# %%
Highest_Sale=df.groupby(['Order Year'],as_index=False)['Units Sold'].sum().sort_values(by='Units Sold',ascending=False)
print(Highest_Sale)
# Out:
#    Order Year  Units Sold
# 2        2012       97967
# 4        2014       92040
# 3        2013       64663
# 0        2010       61571
# 1        2011       54768
# 5        2015       49480
# 7        2017       49226
# 6        2016       43156

# %%
ax = sns.barplot(x='Order Year',y='Units Sold',data=Highest_Sale)
for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# From the above graph analyze that in 2012 the Sales is most

# %%
plt.figure(figsize=(8,10))
x=sns.barplot(data=df,x='Sales Channel', y='Units Sold',hue = 'Order Priority')
for bar in x.containers:
    x.bar_label(bar)

# %% [markdown]
# #We can observe that in Offline sales channel the most sale order priority is 'M'
#
#
#
# #we can observe that in Online sales channel the most sale order priority is 'L'

# %%
sales_channel_units_sold = df.groupby('Sales Channel')['Units Sold'].sum()

plt.figure(figsize=(10, 6))
sales_channel_units_sold.plot(kind='bar', color='skyblue')
plt.title('Sales Channel-wise Units Sold')
plt.xlabel('Sales Channel')
plt.ylabel('Units Sold')
plt.xticks(rotation=0, ha='right')  
plt.tight_layout()
plt.show()

# %% [markdown]
# From the above visualization we can analyze that our sales is more in offline mode as compared to online mode

# %% [markdown]
# # Top10_Sales_Country

# %%
sales_country = df.groupby(['Country'] , as_index = False)['Units Sold'].sum().sort_values(by='Units Sold',ascending = False)
Top10_sales_country = sales_country.head(10)
print(Top10_sales_country )
# Out:
#                   Country  Units Sold
# 59  Sao Tome and Principe       24568
# 16               Djibouti       23198
# 41                 Mexico       19143
# 71             The Gambia       14813
# 46                Myanmar       14180
# 2               Australia       12995
# 50                 Norway       12574
# 24               Honduras       11199
# 10               Cameroon       10948
# 73                 Tuvalu        9925

# %% [markdown]
# # Day wise Sales

# %%
Highest_day_sales=df.groupby(['Order Day'],as_index=False)['Units Sold'].sum().sort_values(by='Units Sold',ascending=False)
Top_days_sales = Highest_day_sales
print(Top_days_sales)
# Out:
#     Order Day  Units Sold
# 7           8       37864
# 16         18       35664
# 6           7       35131
# 12         14       32732
# 15         17       30802
# 28         30       28365
# 18         20       26412
# 24         26       25116
# 23         25       24230
# 14         16       21066
# 26         28       19304
# 0           1       18685
# 21         23       18650
# 11         13       17387
# 29         31       16048
# 5           6       15307
# 10         11       15025
# 17         19       11853
# 27         29       11701
# 13         15       10221
# 4           5       10174
# 22         24        8411
# 20         22        8403
# 1           2        8216
# 3           4        7059
# 2           3        5559
# 9          10        5367
# 19         21        4513
# 25         27        2924
# 8           9         682

# %%
# top_10_States 
top_10_state = df['Country'].value_counts().head(10)
# Plot count of cities by state
plt.figure(figsize=(16, 6))
sns.countplot(data=df[df['Country'].isin(top_10_state.index)], x='Country')
plt.xlabel('country')
plt.ylabel('count')
plt.title('Distribution of  State')
plt.xticks(rotation=45)
plt.show()

# %%
# Prepare data for scatter plot
x_data = df['Order Year']  
y_data = df['Total Profit'] 

# Plot the scatter plot
plt.scatter(x_data, y_data)
plt.xlabel('item type ')  
plt.ylabel('Profit')  
plt.title('Scatter Plot') 
plt.show()

# %%
c=pd.DataFrame(df.groupby('Item Type').sum()['Units Sold'])
print(c)
# Out:
#                  Units Sold
# Item Type
# Baby Food             40545
# Beverages             56708
# Cereal                25877
# Clothes               71260
# Cosmetics             83718
# Fruits                49998
# Household             44727
# Meat                  10675
# Office Supplies       46967
# Personal Care         48708
# Snacks                13637
# Vegetables            20051
# C:\Users\MOHD RAHIL\AppData\Local\Temp\ipykernel_30504\310730382.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   c=pd.DataFrame(df.groupby('Item Type').sum()['Units Sold'])

# %%
v=c.sort_values('Units Sold',ascending=False)
print(v)
# Out:
#                  Units Sold
# Item Type
# Cosmetics             83718
# Clothes               71260
# Beverages             56708
# Fruits                49998
# Personal Care         48708
# Office Supplies       46967
# Household             44727
# Baby Food             40545
# Cereal                25877
# Vegetables            20051
# Snacks                13637
# Meat                  10675

# %%
df.groupby('Order Year').sum()
# Out:
# C:\Users\MOHD RAHIL\AppData\Local\Temp\ipykernel_30504\3658712593.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Order Year').sum()
#                Order ID  Units Sold  Unit Price  Unit Cost  Total Revenue  \
# Order Year
# 2010         5363041038       61571     2868.06    1884.69    19186024.92
# 2011         5696660749       54768     2701.68    1976.81    11129166.07
# 2012        13091153252       97967     7766.50    5632.23    31898644.52
# 2013         6383597653       64663     3818.29    2567.39    20330448.66
# 2014         7974254850       92040     2943.57    1971.26    16630214.43
# 2015         6112829453       49480     2706.04    1833.40    12427982.86
# 2016         5978208036       43156     2713.61    1744.73    12372867.22
# 2017         4902296205       49226     2158.38    1494.29    13373419.63
#
#              Total Cost  Total Profit  Order Month  Order Quarter  Order Day
# Order Year
# 2010        12556457.49    6629567.43           75             28        206
# 2011         8388157.84    2741008.23           79             31        208
# 2012        22685634.40    9213010.12          118             48        354
# 2013        13615028.62    6715420.04           84             32        197
# 2014        10750752.75    5879461.68          100             40        179
# 2015         8431443.42    3996539.44           63             27        199
# 2016         7469029.21    4903838.01           83             30        186
# 2017         9284066.18    4089353.45           24             11        121

# %% [markdown]
# # Month_Year wise Sales Trends

# %%
df['Order Date'].min()
# Out:
# Timestamp('2010-02-02 00:00:00')

# %%
df['Order Date'].max()
# Out:
# Timestamp('2017-05-22 00:00:00')

# %%
df['month_year']=df['Order Date'].apply(lambda x: x.strftime('%Y-%m'))

# %%
sales_trend=df.groupby('month_year').sum()['Units Sold'].reset_index()
# Out:
# C:\Users\MOHD RAHIL\AppData\Local\Temp\ipykernel_30504\1743680648.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sales_trend=df.groupby('month_year').sum()['Units Sold'].reset_index()

# %%
  plt.figure(figsize=(16,5))
plt.plot(sales_trend['month_year'],sales_trend['Units Sold'])
plt.xticks(rotation='vertical',size=10)
print(' '*50+'Month_Year Wise Trend')
plt.show()
# Out:
#                                                   Month_Year Wise Trend

# %% [markdown]
# # Top10 Item Sales

# %%
Item_sales=pd.DataFrame(df.groupby('Item Type').sum()['Units Sold'])
# Out:
# C:\Users\MOHD RAHIL\AppData\Local\Temp\ipykernel_30504\631222159.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   Item_sales=pd.DataFrame(df.groupby('Item Type').sum()['Units Sold'])

# %%
Top_sales=Item_sales.sort_values('Units Sold',ascending=False)

# %%
Top_sales[0:10]
# Out:
#                  Units Sold
# Item Type
# Cosmetics             83718
# Clothes               71260
# Beverages             56708
# Fruits                49998
# Personal Care         48708
# Office Supplies       46967
# Household             44727
# Baby Food             40545
# Cereal                25877
# Vegetables            20051

# %%
pd.DataFrame(df.groupby('Sales Channel').sum()['Units Sold'])
# Out:
# C:\Users\MOHD RAHIL\AppData\Local\Temp\ipykernel_30504\1328805330.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   pd.DataFrame(df.groupby('Sales Channel').sum()['Units Sold'])
#                Units Sold
# Sales Channel
# Offline            276782
# Online             236089

# %%
df.columns
# Out:
# Index(['Region', 'Country', 'Item Type', 'Sales Channel', 'Order Priority',
#        'Order Date', 'Order ID', 'Ship Date', 'Units Sold', 'Unit Price',
#        'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit',
#        'Delivery days', 'Order Year', 'Order Month', 'Order Quarter',
#        'Order Day', 'month_year'],
#       dtype='object')

# %%
Region_sales=pd.DataFrame(df.groupby('Item Type').sum()['Units Sold'])
Top_Region=Region_sales.sort_values('Units Sold',ascending=False)
print(Top_Region)
# Out:
#                  Units Sold
# Item Type
# Cosmetics             83718
# Clothes               71260
# Beverages             56708
# Fruits                49998
# Personal Care         48708
# Office Supplies       46967
# Household             44727
# Baby Food             40545
# Cereal                25877
# Vegetables            20051
# Snacks                13637
# Meat                  10675
# C:\Users\MOHD RAHIL\AppData\Local\Temp\ipykernel_30504\3117145087.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   Region_sales=pd.DataFrame(df.groupby('Item Type').sum()['Units Sold'])

# %%
Region_sales=pd.DataFrame(df.groupby('Region').sum()['Units Sold'])
print(Region_sales)
# Out:
#                                    Units Sold
# Region
# Asia                                    59967
# Australia and Oceania                   68325
# Central America and the Caribbean       35771
# Europe                                  98117
# Middle East and North Africa            48678
# North America                           19143
# Sub-Saharan Africa                     182870
# C:\Users\MOHD RAHIL\AppData\Local\Temp\ipykernel_30504\500376088.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   Region_sales=pd.DataFrame(df.groupby('Region').sum()['Units Sold'])

# %%
Top_Region=Region_sales.sort_values('Units Sold',ascending=False)
print(Top_Region)
# Out:
#                                    Units Sold
# Region
# Sub-Saharan Africa                     182870
# Europe                                  98117
# Australia and Oceania                   68325
# Asia                                    59967
# Middle East and North Africa            48678
# Central America and the Caribbean       35771
# North America                           19143

# %%
country_region_profit=pd.DataFrame(df.groupby(['Region','Country']).sum()['Total Profit'])
# Out:
# C:\Users\MOHD RAHIL\AppData\Local\Temp\ipykernel_30504\3717543686.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   country_region_profit=pd.DataFrame(df.groupby(['Region','Country']).sum()['Total Profit'])

# %%
country_region_profit.sort_values(['Region','Country'],ascending=False)
# Out:
#                                  Total Profit
# Region             Country
# Sub-Saharan Africa Zambia           225246.90
#                    The Gambia      1385883.27
#                    South Sudan       53252.50
#                    Sierra Leone     649879.30
#                    Senegal          584073.87
# ...                                       ...
# Asia               Malaysia          15103.47
#                    Laos             235601.16
#                    Kyrgyzstan         7828.12
#                    Brunei           846885.00
#                    Bangladesh       606834.72
#
# [76 rows x 1 columns]

# %%
df.groupby('Region').sum()['Units Sold']
# Out:
# C:\Users\MOHD RAHIL\AppData\Local\Temp\ipykernel_30504\3411287863.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Region').sum()['Units Sold']
# Region
# Asia                                  59967
# Australia and Oceania                 68325
# Central America and the Caribbean     35771
# Europe                                98117
# Middle East and North Africa          48678
# North America                         19143
# Sub-Saharan Africa                   182870
# Name: Units Sold, dtype: int64

# %%
Order_Date = pd.to_datetime(df['Order Date']).dt.date
print(Order_Date)
# Out:
# 0     2010-05-28
# 1     2012-08-22
# 2     2014-05-02
# 3     2014-06-20
# 4     2013-02-01
#          ...
# 95    2011-07-26
# 96    2011-11-11
# 97    2016-06-01
# 98    2015-07-30
# 99    2012-02-10
# Name: Order Date, Length: 100, dtype: object

# %%
Order_Day= pd.to_datetime(df['Order Date']).dt.date
top10sales = df.groupby('Order Date').sum().sort_values('Units Sold', ascending = False)
top10sales = top10sales.reset_index().head(10)
print(top10sales)
# Out:
#   Order Date   Order ID  Units Sold  Unit Price  Unit Cost  Total Revenue  \
# 0 2010-05-28  669165933        9925      255.28     159.42     2533654.00
# 1 2010-06-30  647876489        9905      109.28      35.84     1082418.40
# 2 2013-07-05  231145322        9892      437.20     263.33     4324782.40
# 3 2013-07-20  670854651        9654      437.20     263.33     4220728.80
# 4 2013-08-18  918419539        9606        9.33       6.92       89623.98
# 5 2014-07-07  240470397        9389       47.45      31.79      445508.05
# 6 2014-10-28  217221009        9379       47.45      31.79      445033.55
# 7 2017-02-08  522840487        8974      668.27     502.54     5997054.98
# 8 2016-12-31  331438481        8867      437.20     263.33     3876652.40
# 9 2011-01-16  180283772        8829       47.45      31.79      418936.05
#
#    Total Cost  Total Profit  Order Year  Order Month  Order Quarter  Order Day
# 0  1582243.50     951410.50        2010            5              2         28
# 1   354995.20     727423.20        2010            6              2         30
# 2  2604860.36    1719922.04        2013            7              3          5
# 3  2542187.82    1678540.98        2013            7              3         20
# 4    66473.52      23150.46        2013            8              3         18
# 5   298476.31     147031.74        2014            7              3          7
# 6   298158.41     146875.14        2014           10              4         28
# 7  4509793.96    1487261.02        2017            2              1          8
# 8  2334947.11    1541705.29        2016           12              4         31
# 9   280673.91     138262.14        2011            1              1         16
# C:\Users\MOHD RAHIL\AppData\Local\Temp\ipykernel_30504\252388700.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   top10sales = df.groupby('Order Date').sum().sort_values('Units Sold', ascending = False)

# %%
y = top10sales.groupby(['Order Date'])['Units Sold'].sum().nlargest(10)
y.plot.barh()
# Out:
# <Axes: ylabel='Order Date'>

# %% [markdown]
# From the above graph analyze that the most sales sold on 2013-07-05

# %%
plt.figure(figsize=(18,7))
plt.pie('Units Sold',labels='Order Date',data = top10sales,
        autopct='%1.2f%%',shadow=True,startangle=90)
plt.axis('equal')
plt.title('Contribution Of Sales Amount Among 10 Days')
plt.legend(round(top10sales['Units Sold'],2), loc=7, fontsize = 'x-large')
plt.show()

# %%
Order_Day= pd.to_datetime(df['Order Date']).dt.date
top10sales = df.groupby('Order Date').sum().sort_values('Total Profit', ascending = False)
top10sales = top10sales.reset_index().head(10)
print(top10sales)
# Out:
#   Order Date   Order ID  Units Sold  Unit Price  Unit Cost  Total Revenue  \
# 0 2013-07-05  231145322        9892      437.20     263.33     4324782.40
# 1 2013-07-20  670854651        9654      437.20     263.33     4220728.80
# 2 2016-12-31  331438481        8867      437.20     263.33     3876652.40
# 3 2012-09-17  249693334        8661      437.20     263.33     3786589.20
# 4 2017-02-08  522840487        8974      668.27     502.54     5997054.98
# 5 2010-11-26  660643374        7910      437.20     263.33     3458252.00
# 6 2015-01-16  177713572        8250      668.27     502.54     5513227.50
# 7 2010-02-06  382392299        7234      437.20     263.33     3162704.80
# 8 2014-04-07  259353148        7215      437.20     263.33     3154398.00
# 9 2016-11-19  419123971        6952      437.20     263.33     3039414.40
#
#    Total Cost  Total Profit  Order Year  Order Month  Order Quarter  Order Day
# 0  2604860.36    1719922.04        2013            7              3          5
# 1  2542187.82    1678540.98        2013            7              3         20
# 2  2334947.11    1541705.29        2016           12              4         31
# 3  2280701.13    1505888.07        2012            9              3         17
# 4  4509793.96    1487261.02        2017            2              1          8
# 5  2082940.30    1375311.70        2010           11              4         26
# 6  4145955.00    1367272.50        2015            1              1         16
# 7  1904929.22    1257775.58        2010            2              1          6
# 8  1899925.95    1254472.05        2014            4              2          7
# 9  1830670.16    1208744.24        2016           11              4         19
# C:\Users\MOHD RAHIL\AppData\Local\Temp\ipykernel_30504\4216958357.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   top10sales = df.groupby('Order Date').sum().sort_values('Total Profit', ascending = False)

# %%
plt.figure(figsize=(18,7))
plt.pie('Total Profit',labels='Order Date',data = top10sales,
        autopct='%1.2f%%',shadow=True,startangle=90)
plt.axis('equal')
plt.title('Contribution Of Sales Amount Among 10 Days')
plt.legend(round(top10sales['Total Profit'],2), loc=7, fontsize = 'x-large')
plt.show()

# %%
Order_Day= pd.to_datetime(df['Order Date']).dt.date
top10sales = df.groupby('Order Date').sum().sort_values('Total Revenue', ascending = False)
top10sales = top10sales.reset_index().head(10)
print(top10sales)
# Out:
#   Order Date   Order ID  Units Sold  Unit Price  Unit Cost  Total Revenue  \
# 0 2017-02-08  522840487        8974      668.27     502.54     5997054.98
# 1 2015-01-16  177713572        8250      668.27     502.54     5513227.50
# 2 2010-10-24  166460740        8287      651.21     524.96     5396577.27
# 3 2014-11-06  986435210        6954      668.27     502.54     4647149.58
# 4 2012-04-01  320009267        6708      651.21     524.96     4368316.68
# 5 2013-07-05  231145322        9892      437.20     263.33     4324782.40
# 6 2013-07-20  670854651        9654      437.20     263.33     4220728.80
# 7 2016-12-31  331438481        8867      437.20     263.33     3876652.40
# 8 2012-09-17  249693334        8661      437.20     263.33     3786589.20
# 9 2011-11-07  177636754        5518      651.21     524.96     3593376.78
#
#    Total Cost  Total Profit  Order Year  Order Month  Order Quarter  Order Day
# 0  4509793.96    1487261.02        2017            2              1          8
# 1  4145955.00    1367272.50        2015            1              1         16
# 2  4350343.52    1046233.75        2010           10              4         24
# 3  3494663.16    1152486.42        2014           11              4          6
# 4  3521431.68     846885.00        2012            4              2          1
# 5  2604860.36    1719922.04        2013            7              3          5
# 6  2542187.82    1678540.98        2013            7              3         20
# 7  2334947.11    1541705.29        2016           12              4         31
# 8  2280701.13    1505888.07        2012            9              3         17
# 9  2896729.28     696647.50        2011           11              4          7
# C:\Users\MOHD RAHIL\AppData\Local\Temp\ipykernel_30504\638360942.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   top10sales = df.groupby('Order Date').sum().sort_values('Total Revenue', ascending = False)

# %%
plt.figure(figsize=(18,7))
plt.pie('Total Revenue',labels='Order Date',data = top10sales,
        autopct='%1.2f%%',shadow=True,startangle=90)
plt.axis('equal')
plt.title('Contribution Of Sales Amount Among 10 Days')
plt.legend(round(top10sales['Total Revenue'],2), loc=7, fontsize = 'x-large')
plt.show()

# %%
df.groupby('Country').sum().sort_values('Total Profit',ascending=False).head(10)
# Out:
# C:\Users\MOHD RAHIL\AppData\Local\Temp\ipykernel_30504\3558168925.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Country').sum().sort_values('Total Profit',ascending=False).head(10)
#                Order ID  Units Sold  Unit Price  Unit Cost  Total Revenue  \
# Country
# Djibouti     1571617804       23198      795.48     477.88     6052890.86
# Myanmar       401073192       14180      777.55     538.38     6161257.90
# Pakistan      231145322        9892      437.20     263.33     4324782.40
# Samoa         670854651        9654      437.20     263.33     4220728.80
# Honduras     1318331169       11199      820.85     599.98     6336545.48
# Iceland       331438481        8867      437.20     263.33     3876652.40
# Azerbaijan    805723690        9255     1088.41     788.29     4478800.21
# Switzerland   867360424        8934      518.93     320.00     3808901.49
# Mexico       1976778136       19143      831.73     615.88     5643356.55
# Rwanda        814814877        9539     1088.41     788.29     5253769.42
#
#              Total Cost  Total Profit  Order Year  Order Month  Order Quarter  \
# Country
# Djibouti     3627572.99    2425317.87        6048           11              5
# Myanmar      4358486.20    1802771.70        4030           12              5
# Pakistan     2604860.36    1719922.04        2013            7              3
# Samoa        2542187.82    1678540.98        2013            7              3
# Honduras     4726597.96    1609947.52        4033            8              3
# Iceland      2334947.11    1541705.29        2016           12              4
# Azerbaijan   2965873.38    1512926.83        4022            8              3
# Switzerland  2296172.04    1512729.45        4022           21              7
# Mexico       4185413.79    1457942.76        6041           20              8
# Rwanda       3836275.93    1417493.49        4026           12              5
#
#              Order Day
# Country
# Djibouti            52
# Myanmar             30
# Pakistan             5
# Samoa               20
# Honduras            38
# Iceland             31
# Azerbaijan          19
# Switzerland         40
# Mexico              53
# Rwanda              12

# %% [markdown]
# # Region Wise Total Profit

# %%
region_wise = df.groupby(['Region'])['Total Profit'].sum()
region_wise.plot.barh()
# Out:
# <Axes: ylabel='Region'>

# %% [markdown]
# From the above visulization we can analyze that the Sub-Saharan Africa is the Most Profitable region

# %%
top_country_profit = df.groupby("Country")['Total Profit'].sum().head(10)
print(top_country_profit)
# Out:
# Country
# Albania          166635.36
# Angola           693911.51
# Australia        576605.12
# Austria          495007.89
# Azerbaijan      1512926.83
# Bangladesh       606834.72
# Belize           403773.12
# Brunei           846885.00
# Bulgaria         626223.87
# Burkina Faso     510216.66
# Name: Total Profit, dtype: float64

# %%
Region_sales=pd.DataFrame(df.groupby('Item Type').sum()['Units Sold'])
Top_Region=Region_sales.sort_values('Units Sold',ascending=False)
print(Top_Region)
# Out:
#                  Units Sold
# Item Type
# Cosmetics             83718
# Clothes               71260
# Beverages             56708
# Fruits                49998
# Personal Care         48708
# Office Supplies       46967
# Household             44727
# Baby Food             40545
# Cereal                25877
# Vegetables            20051
# Snacks                13637
# Meat                  10675
# C:\Users\MOHD RAHIL\AppData\Local\Temp\ipykernel_30504\2473554689.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   Region_sales=pd.DataFrame(df.groupby('Item Type').sum()['Units Sold'])

# %%
plt.figure(figsize=(14,10)) 
statewise = df.groupby(['Item Type'])['Total Profit'].sum().nlargest(100) 
statewise.plot.barh() # h for horizontal
# Out:
# <Axes: ylabel='Item Type'>

# %% [markdown]
# hence From the above visulization cosmetic product is the most Profitable product from all the item

# %%
Year_wise_Sales=df.groupby('Order Year').sum().reset_index()
sns.catplot(y = 'Units Sold', x = 'Order Year', data = df, palette='Reds',kind="bar")
plt.xlabel('Year')
plt.ylabel('Units Sold')
plt.title('Yearly Sales')
Year_wise_Sales[['Order Year', 'Units Sold']]
# Out:
# C:\Users\MOHD RAHIL\AppData\Local\Temp\ipykernel_30504\2695195162.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   Year_wise_Sales=df.groupby('Order Year').sum().reset_index()
#    Order Year  Units Sold
# 0        2010       61571
# 1        2011       54768
# 2        2012       97967
# 3        2013       64663
# 4        2014       92040
# 5        2015       49480
# 6        2016       43156
# 7        2017       49226

# %%
year_monthwise_sales = df.groupby(['Order Year','Order Month']).sum().reset_index()
print(year_monthwise_sales)
# Out:
#     Order Year  Order Month    Order ID  Units Sold  Unit Price  Unit Cost  \
# 0         2010            2   767775368        9503      546.48     299.17
# 1         2010            5  1355214333       15747      264.61     166.34
# 2         2010            6   647876489        9905      109.28      35.84
# 3         2010           10   872245048       14403      760.49     560.80
# 4         2010           11   660643374        7910      437.20     263.33
# 5         2010           12  1059286426        4103      750.00     559.21
# 6         2011            1   302867435       12914      200.03     129.23
# 7         2011            2   963392674        8156       47.45      31.79
# 8         2011            4   135425221        4187      668.27     502.54
# 9         2011            5   585920464        5741       47.45      31.79
# 10        2011            6   814711606         124      154.06      90.93
# 11        2011            7   512878119         888      109.28      35.84
# 12        2011            9   789176547        3732      154.06      90.93
# 13        2011           11  1592288683       19026     1321.08    1063.76
# 14        2012            1  1792916511        1548     1319.48    1027.50
# 15        2012            2  1285977135       15776     1401.21    1084.17
# 16        2012            3   827844560        6457      154.06      90.93
# 17        2012            4  1805718861        8903      769.82     567.72
# 18        2012            5  1574782967       10984      923.55     661.96
# 19        2012            6  1531960164        7620      966.19     677.91
# 20        2012            7  1422556506       22646      657.68     512.29
# 21        2012            8   963881480        2804      205.70     117.11
# 22        2012            9   912803482       16545      546.48     299.17
# 23        2012           10   972711586        4684      822.33     593.47
# 24        2013            2   115456712        5062      651.21     524.96
# 25        2013            3   844530045        4063      205.70     117.11
# 26        2013            4   462405812        5010      651.21     524.96
# 27        2013            6  1020226597        5432      460.98     276.53
# 28        2013            7   901999973       19546      874.40     526.66
# 29        2013            8   918419539        9606        9.33       6.92
# 30        2013            9   508980977        7637        9.33       6.92
# 31        2013           10  1205075001        6182      874.40     526.66
# 32        2013           12   406502997        2125       81.73      56.67
# 33        2014            2  1327148556       10460      337.01     216.09
# 34        2014            4   875960229       13808      642.90     380.44
# 35        2014            5  1160445188        9229      906.49     684.38
# 36        2014            6   514321792        8102        9.33       6.92
# 37        2014            7   676079010       14513       94.90      63.58
# 38        2014            8   939825713        4168      109.28      35.84
# 39        2014            9   142278373        2187        9.33       6.92
# 40        2014           10  1351760779       22619      166.06      74.55
# 41        2014           11   986435210        6954      668.27     502.54
# 42        2015            1   177713572        8250      668.27     502.54
# 43        2015            2  1416210341        5821      692.48     422.75
# 44        2015            4  1130246519       12772      156.73      67.63
# 45        2015            7  2190563928       13110      418.74     272.76
# 46        2015            8   816200339         673        9.33       6.92
# 47        2015           10   158535134        2924      651.21     524.96
# 48        2015           11   223359620        5930      109.28      35.84
# 49        2016            3   902102267         962      205.70     117.11
# 50        2016            5   740147912        5070       81.73      56.67
# 51        2016            6  1524305939        3710      306.64     188.37
# 52        2016            7   807025039        5498      109.28      35.84
# 53        2016           10   345718562        4660       47.45      31.79
# 54        2016           11   706083273       13441      874.40     526.66
# 55        2016           12   952825044        9815     1088.41     788.29
# 56        2017            1  1012615131       13030      531.17     400.53
# 57        2017            2  1279115127       16301      820.85     599.98
# 58        2017            3   699285638        3015       81.73      56.67
# 59        2017            5  1911280309       16880      724.63     437.11
#
#     Total Revenue  Total Cost  Total Profit  Order Quarter  Order Day
# 0      3410661.12  1986250.18    1424410.94              2          8
# 1      2587973.26  1622531.74     965441.52              4         35
# 2      1082418.40   354995.20     727423.20              2         30
# 3      6064933.75  4569540.96    1495392.79              8         54
# 4      3458252.00  2082940.30    1375311.70              4         26
# 5      2581786.39  1940199.11     641587.28              8         53
# 6      1042225.35   678716.31     363509.04              2         20
# 7       387002.20   259279.24     127722.96              1          8
# 8      2798046.49  2104134.98     693911.51              2         23
# 9       272410.45   182506.39      89904.06              2         26
# 10       19103.44    11275.32       7828.12              2         24
# 11       97040.64    31825.92      65214.72              3         26
# 12      574951.92   339350.76     235601.16              3         15
# 13     5938385.58  4781068.92    1157316.66             16         66
# 14     1012884.00   806315.64     206568.36              2         16
# 15     6707849.42  5154082.44    1553766.98              3         43
# 16      994765.42   587135.01     407630.41              1         18
# 17     4556012.38  3585004.24     971008.14              6         54
# 18     3782781.82  2564263.68    1218518.14              4         55
# 19     2132075.27  1433660.91     698414.36              6         28
# 20     4445093.92  3380020.30    1065073.62              9         56
# 21      576782.80   328376.44     248406.36              3         22
# 22     4648152.72  2563263.69    2084889.03              6         35
# 23     3042246.77  2283512.05     758734.72              8         27
# 24     3296425.02  2657347.52     639077.50              1          1
# 25      835759.10   475817.93     359941.17              1         25
# 26     3262562.10  2630049.60     632512.50              2         23
# 27     1352867.40   837114.02     515753.38              4         35
# 28     8545511.20  5147048.18    3398463.02              6         25
# 29       89623.98    66473.52      23150.46              3         18
# 30       71253.21    52848.04      18405.17              3         17
# 31     2702770.40  1627906.06    1074864.34              8         24
# 32      173676.25   120423.75      53252.50              4         29
# 33     1819660.25  1163955.45     655704.80              2         22
# 34     4510578.10  2672032.18    1838545.92              4         25
# 35     3060338.59  2121582.84     938755.75              4         16
# 36       75591.66    56065.84      19525.82              2         20
# 37      688641.85   461368.27     227273.58              6         25
# 38      455479.04   149381.12     306097.92              3          2
# 39       20404.71    15134.04       5270.67              3          8
# 40     1352370.65   616569.85     735800.80             12         55
# 41     4647149.58  3494663.16    1152486.42              4          6
# 42     5513227.50  4145955.00    1367272.50              1         16
# 43     2003911.12  1223815.59     780095.53              2         27
# 44     1059987.26   435756.98     624230.28              4         26
# 45     1292409.45   873744.45     418665.00              9         75
# 46        6279.09     4657.16       1621.93              3         14
# 47     1904138.04  1534983.04     369155.00              4         27
# 48      648030.40   212531.20     435499.20              4         14
# 49      197883.40   112659.82      85223.58              1         29
# 50      414371.10   287316.90     127054.20              2          7
# 51      568269.60   351835.05     216434.55              4         31
# 52      600821.44   197048.32     403773.12              3         25
# 53      221117.00   148141.40      72975.60              4         23
# 54     5876405.20  3539418.53    2336986.67              8         34
# 55     4493999.48  2832609.19    1661390.29              8         37
# 56     2914130.27  2034623.15     879507.12              2         27
# 57     7115008.64  5223736.84    1891271.80              2         33
# 58      246415.95   170860.05      75555.90              1         11
# 59     3097864.77  1854846.14    1243018.63              6         50
# C:\Users\MOHD RAHIL\AppData\Local\Temp\ipykernel_30504\307413475.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   year_monthwise_sales = df.groupby(['Order Year','Order Month']).sum().reset_index()

# %%
sns.relplot(x ='Order Month',y = 'Units Sold', data=year_monthwise_sales,height=5,
            kind = 'line', aspect = 0.4, col = 'Order Year')
plt.xlabel('Order Month')
plt.ylabel('Units Sold')
print( ' '*40  +'Year Wise Month Trends')
# Out:
#                                         Year Wise Month Trends

# %%
sns.catplot(y = 'Units Sold', x = 'Order Month', data = year_monthwise_sales, aspect=2.0,palette='turbo',kind="bar",
            col='Order Year', col_wrap=3)

# %%
sns.histplot(year_monthwise_sales['Units Sold'], kde = True)
# Out:
# <Axes: xlabel='Units Sold', ylabel='Count'>

# %% [markdown]
# # Monthly-Wise Record

# %%
Monthwise_sales=df.groupby(['Order Year','Order Month','Order Day']).sum().reset_index()
# Out:
# C:\Users\MOHD RAHIL\AppData\Local\Temp\ipykernel_30504\899927217.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   Monthwise_sales=df.groupby(['Order Year','Order Month','Order Day']).sum().reset_index()

# %%
Monthwise_sales.describe()
# Out:
#         Order Year  Order Month   Order Day      Order ID   Units Sold  \
# count   100.000000   100.000000  100.000000  1.000000e+02   100.000000
# mean   2013.230000     6.260000   16.500000  5.550204e+08  5128.710000
# std       2.088231     3.353334    8.997755  2.606153e+08  2794.484562
# min    2010.000000     1.000000    1.000000  1.146066e+08   124.000000
# 25%    2012.000000     4.000000    8.000000  3.389225e+08  2836.250000
# 50%    2013.000000     6.000000   17.000000  5.577086e+08  5382.500000
# 75%    2015.000000     9.250000   24.250000  7.907551e+08  7369.000000
# max    2017.000000    12.000000   31.000000  9.940222e+08  9925.000000
#
#        Unit Price   Unit Cost  Total Revenue    Total Cost  Total Profit  \
# count  100.000000  100.000000   1.000000e+02  1.000000e+02  1.000000e+02
# mean   276.761300  191.048000   1.373488e+06  9.318057e+05  4.416820e+05
# std    235.592241  188.208181   1.460029e+06  1.083938e+06  4.385379e+05
# min      9.330000    6.920000   4.870260e+03  3.612240e+03  1.258020e+03
# 25%     81.730000   35.840000   2.687212e+05  1.688680e+05  1.214436e+05
# 50%    179.880000  107.275000   7.523144e+05  3.635664e+05  2.907680e+05
# 75%    437.200000  263.330000   2.212045e+06  1.613870e+06  6.358288e+05
# max    668.270000  524.960000   5.997055e+06  4.509794e+06  1.719922e+06
#
#        Order Quarter
# count     100.000000
# mean        2.470000
# std         1.114233
# min         1.000000
# 25%         2.000000
# 50%         2.000000
# 75%         3.250000
# max         4.000000

# %%
monthwise_sales=df.groupby(['Order Year', 'Order Month'])['Units Sold'].sum().reset_index()

# %%
plt.figure(figsize=(15,4))
sns.set_style("whitegrid")

# Plot each year separately
for year in monthwise_sales['Order Year'].unique():
    year_data = monthwise_sales[monthly_sales['Order Year'] == year]
    sns.lineplot(x='Order Month', y='Units Sold', data=year_data, label=str(year))

plt.title('Monthly Sales on Amazon Year-wise')
plt.xlabel('Month')
plt.ylabel('Units Sold')
plt.xticks(range(1, 13), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.legend(title='Year')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Analyzing Month Trend Sales with each Year Separately

# %%
plt.figure(figsize=(6, 4))
sns.set_style("whitegrid")

# Plot each year separately
for year in monthwise_sales['Order Year'].unique():
    year_data = monthwise_sales[monthly_sales['Order Year'] == 2010]
    sns.lineplot(x='Order Month', y='Units Sold', data=year_data)

plt.title('Monthly Sales on Amazon 2010')
plt.xlabel('Month')
plt.ylabel('Units Sold')
plt.xticks(range(1, 13), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.legend(title='Year')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.figure(figsize=(6, 4))
sns.set_style("whitegrid")

# Plot each year separately
for year in monthwise_sales['Order Year'].unique():
    year_data = monthwise_sales[monthly_sales['Order Year'] == 2011]
    sns.lineplot(x='Order Month', y='Units Sold', data=year_data)

plt.title('Monthly Sales on Amazon 2011')
plt.xlabel('Month')
plt.ylabel('Units Sold')
plt.xticks(range(1, 13), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.set_style("whitegrid")

# Plot each year separately
for year in monthwise_sales['Order Year'].unique():
    year_data = monthwise_sales[monthly_sales['Order Year'] == 2012]
    sns.lineplot(x='Order Month', y='Units Sold', data=year_data)

plt.title('Monthly Sales on Amazon 2012')
plt.xlabel('Month')
plt.ylabel('Units Sold')
plt.xticks(range(1, 13), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])

plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.set_style("whitegrid")

# Plot each year separately
for year in monthwise_sales['Order Year'].unique():
    year_data = monthwise_sales[monthly_sales['Order Year'] == 2013]
    sns.lineplot(x='Order Month', y='Units Sold', data=year_data)

plt.title('Monthly Sales on Amazon 2013')
plt.xlabel('Month')
plt.ylabel('Units Sold')
plt.xticks(range(1, 13), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.set_style("whitegrid")

# Plot each year separately
for year in monthwise_sales['Order Year'].unique():
    year_data = monthwise_sales[monthly_sales['Order Year'] == 2014]
    sns.lineplot(x='Order Month', y='Units Sold', data=year_data)

plt.title('Monthly Sales on Amazon 2014')
plt.xlabel('Month')
plt.ylabel('Units Sold')
plt.xticks(range(1, 13), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.set_style("whitegrid")

# Plot each year separately
for year in monthwise_sales['Order Year'].unique():
    year_data = monthwise_sales[monthly_sales['Order Year'] == 2015]
    sns.lineplot(x='Order Month', y='Units Sold', data=year_data)

plt.title('Monthly Sales on Amazon 2015')
plt.xlabel('Month')
plt.ylabel('Units Sold')
plt.xticks(range(1, 13), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.set_style("whitegrid")

# Plot each year separately
for year in monthwise_sales['Order Year'].unique():
    year_data = monthwise_sales[monthly_sales['Order Year'] == 2016]
    sns.lineplot(x='Order Month', y='Units Sold', data=year_data)

plt.title('Monthly Sales on Amazon 2016')
plt.xlabel('Month')
plt.ylabel('Units Sold')
plt.xticks(range(1, 13), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.set_style("whitegrid")

# Plot each year separately
for year in monthwise_sales['Order Year'].unique():
    year_data = monthwise_sales[monthly_sales['Order Year'] == 2017]
    sns.lineplot(x='Order Month', y='Units Sold', data=year_data)

plt.title('Monthly Sales on Amazon 2017')
plt.xlabel('Month')
plt.ylabel('Units Sold')
plt.xticks(range(1, 13), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.show()

# %% [markdown]
# # Year-Wise Sales Trends

# %%
yearly_sales = df.groupby('Order Year')['Units Sold'].sum().reset_index()
print(yearly_sales)
# Out:
#    Order Year  Units Sold
# 0        2010       61571
# 1        2011       54768
# 2        2012       97967
# 3        2013       64663
# 4        2014       92040
# 5        2015       49480
# 6        2016       43156
# 7        2017       49226

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Order Year', y='Units Sold', data=yearly_sales, palette='viridis')
plt.title('Yearly Total Sales on Amazon')
plt.xlabel('Year')
plt.ylabel('Total Sales Amount ($)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x='Order Year', y='Units Sold', data=yearly_sales, marker='o', color='skyblue')
plt.title('Yearly Total Sales on Amazon')
plt.xlabel('Year')
plt.ylabel('Total Sales Amount ($)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 4))
plt.pie(yearly_sales['Units Sold'], labels=yearly_sales['Order Year'], autopct='%1.1f%%', startangle=140)
plt.axis('equal')
plt.title('Yearly Total Sales Distribution on Amazon')
plt.tight_layout()
plt.show()

# %%
yearly_sales = df.groupby('Order Year')['Total Profit'].sum().reset_index()
print(yearly_sales)
# Out:
#    Order Year  Total Profit
# 0        2010    6629567.43
# 1        2011    2741008.23
# 2        2012    9213010.12
# 3        2013    6715420.04
# 4        2014    5879461.68
# 5        2015    3996539.44
# 6        2016    4903838.01
# 7        2017    4089353.45

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Order Year', y='Total Profit', data=yearly_sales, palette='viridis')
plt.title('Yearly Total Sales on Amazon')
plt.xlabel('Year')
plt.ylabel('Total Sales')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 4))
plt.pie(yearly_sales['Total Profit'], labels=yearly_sales['Order Year'], autopct='%1.1f%%', startangle=140)
plt.axis('equal')
plt.title('Yearly Total Profit Distribution on Amazon')
plt.tight_layout()
plt.show()

# %%
df.columns
# Out:
# Index(['Region', 'Country', 'Item Type', 'Sales Channel', 'Order Priority',
#        'Order Date', 'Order ID', 'Ship Date', 'Units Sold', 'Unit Price',
#        'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit',
#        'Delivery days', 'Order Year', 'Order Month', 'Order Quarter',
#        'Order Day', 'month_year'],
#       dtype='object')

# %%
yearly_sales = df.groupby('Order Year')['Total Profit'].sum().reset_index()
print(yearly_sales)
# Out:
#    Order Year  Total Profit
# 0        2010    6629567.43
# 1        2011    2741008.23
# 2        2012    9213010.12
# 3        2013    6715420.04
# 4        2014    5879461.68
# 5        2015    3996539.44
# 6        2016    4903838.01
# 7        2017    4089353.45

# %%
plt.figure(figsize=(14,10)) 
statewise = yearly_sales.groupby(['Order Year'])['Total Profit'].sum()
statewise.plot.barh()
# Out:
# <Axes: ylabel='Order Year'>

# %% [markdown]
# IN 2012 We got The Most Profit It was the Most Profitable Year

# %%
yearly_item_sales = df.groupby(['Order Year', 'Item Type']).sum()['Units Sold'].reset_index()
print(yearly_item_sales)
# Out:
#     Order Year      Item Type  Units Sold
# 0         2010      Baby Food        9925
# 1         2010        Clothes       18290
# 2         2010      Cosmetics       15144
# 3         2010         Fruits        5822
# 4         2010      Household        3830
# ..         ...            ...         ...
# 57        2017      Cosmetics        1815
# 58        2017      Household        8974
# 59        2017           Meat        4767
# 60        2017  Personal Care        9424
# 61        2017         Snacks        7327
#
# [62 rows x 3 columns]
# C:\Users\MOHD RAHIL\AppData\Local\Temp\ipykernel_30504\4218116923.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   yearly_item_sales = df.groupby(['Order Year', 'Item Type']).sum()['Units Sold'].reset_index()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=yearly_item_sales, x='Order Year', y='Units Sold', hue='Item Type')
plt.title('Most Sold Product Each Year')
plt.xlabel('Year')
plt.ylabel('Units Sold')
plt.legend(title='Product')
plt.show()

# %% [markdown]
# From the above visualization we analyze the most sale product year wise as given below
#
# 2010 = 'Clothes'
# 2011 = 'Beverages'
# 2012 = 'Personal Care'
# 2013 = 'Cosmetics'
# 2014 = 'Beverages'
# 2015 = 'Clothes'
# 2016 = 'Cosmetics'
# 2017 = 'Personal Care'

# %%
yearly_sales = df.groupby(['Order Year', 'Item Type'])['Units Sold'].sum().reset_index()

# Find the most sold item for each year
most_sold_per_year = yearly_sales.loc[yearly_sales.groupby('Order Year')['Units Sold'].idxmax()]

# Print the results
print(most_sold_per_year)
# Out:
#     Order Year      Item Type  Units Sold
# 1         2010        Clothes       18290
# 7         2011      Beverages       22726
# 22        2012  Personal Care       15078
# 26        2013      Cosmetics       25728
# 31        2014      Beverages       23892
# 41        2015        Clothes       13272
# 50        2016      Cosmetics       22308
# 60        2017  Personal Care        9424

# %%
df.columns
# Out:
# Index(['Region', 'Country', 'Item Type', 'Sales Channel', 'Order Priority',
#        'Order Date', 'Order ID', 'Ship Date', 'Units Sold', 'Unit Price',
#        'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit',
#        'Delivery days', 'Order Year', 'Order Month', 'Order Quarter',
#        'Order Day', 'month_year'],
#       dtype='object')

# %% [markdown]
# # Forecasting Sales And Profit

# %%
from prophet import Prophet

# %%
 df['date'] =pd.to_datetime(df['Order Date'])

# %%
sales_data = df.rename(columns={'Order Date': 'ds', 'Units Sold': 'y'})

# %%
model = Prophet()

# %%
model.fit(sales_data)
# Out:
# 22:45:06 - cmdstanpy - INFO - Chain [1] start processing
# 22:45:06 - cmdstanpy - INFO - Chain [1] done processing

# %%
profit_data = df.rename(columns={'Order Date': 'ds', 'Total Profit': 'y'})
model = Prophet()
model.fit(profit_data)
future = model.make_future_dataframe(periods=365*4)
forecast = model.predict(future)
fig = model.plot(forecast)
# Out:
# 22:45:06 - cmdstanpy - INFO - Chain [1] start processing
# 22:45:06 - cmdstanpy - INFO - Chain [1] done processing

# %%
profit_data = df.rename(columns={'Order Date': 'ds', 'Units Sold': 'y'})
model = Prophet()
model.fit(profit_data)
future = model.make_future_dataframe(periods=365*4)
forecast = model.predict(future)
fig = model.plot(forecast)
# Out:
# 22:45:08 - cmdstanpy - INFO - Chain [1] start processing
# 22:45:08 - cmdstanpy - INFO - Chain [1] done processing
